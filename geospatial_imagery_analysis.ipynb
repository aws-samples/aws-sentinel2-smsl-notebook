# %% [markdown]
# # Getting Started With Geospatial Data Analysis
#
# This notebook is part of an original blog post [Getting Started with Geospatial Analysis on SageMaker Studio Lab](https://towardsdatascience.com/getting-started-with-geospatial-analysis-b2116c50308b) which covers the basics of getting started with Geospatial Data Analysis on SageMaker Studio Labs. For this demonstration we focus solely on working with Sentinel-2 imagery available from the Registry of Open Data on AWS using the [SentinelHub API]((https://www.sentinel-hub.com/) to query and download before/after scenes over Mt. Shasta in California during the Lava Fire that impacted the region in June 2021. We then compare two images, one prior to the wildfire and another after, calculating a spectral index to identify vegetation and classify the resulting NDVI image into simple land cover classification image.

# %% [markdown]
# ## Install Packages (Optional)
# Creating a environment in Studio Lab is easy, just select the environment.yml file (by cloning this repository or upload it directly), right click the YAML file and select create environment. Once the environment is created, you should open this notbook with the newly created kernel. Optionally you can also uncomment the package installation section of the notebook to install these packages manually.

# %%
# %pip install numpy
# %pip install matplotlib
# %pip install plotly_express
# %pip install sentinelhub
# %pip install rasterio
# %pip install earthpy

# %% [markdown]
# ## Import Packages
# After the environment is created and selected or the packages installed manually, we can import them directly.

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import folium
import plotly_express as px
import os
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Working With Geospatial Images
# For Geospatial data, we will use Sentinel-2. The [Sentinel-2 mission](https://sentinel.esa.int/web/sentinel/missions/sentinel-2) is a land monitoring constellation of two satellites that provide high resolution optical imagery and continuity for the current SPOT and Landsat missions. The Sentinel-2 dataset is available publicly at the [AWS open data registry](https://registry.opendata.aws/sentinel-2/).

# %% [markdown]
# We will use the `sentinelhub` python package, that makes it easy to search and download data specific to our focus area directly from AWS.

# %%
from sentinelhub import SHConfig
config = SHConfig()

# %% [markdown]
# #### Sentinel Hub Setup
# This section shows how to configure your credentials for sentinelhub. We are using a optional json file to store and retrieve credentials.

# %%
import json

with open("config.json") as json_data_file:
    cfg = json.load(json_data_file)

# %%
# instance_id - Instance ID from from your Sentinel Hub account 
# aws_access_key_id - Access key ID from your AWS account
# aws_secret_access_key - Secrect access key from your AWS account

config.instance_id = cfg["sentinelhub"]["instance_id"]
config.aws_access_key_id = cfg["aws"]["access_key_id"]
config.aws_secret_access_key = cfg["aws"]["secret_access_key"]

# %%
# Save the configuration
config.save()

# %%
# Verify credentials

from sentinelhub import WebFeatureService, BBox, CRS, DataCollection, SHConfig
if config.instance_id == '':
    print("Warning! To use WFS functionality, please configure the `instance_id`.")

# %% [markdown]
# #### Data Search
# Before we download, we need to specify our search coordinates that we want to study and the time window. In our case we are focusing on the Mt. Shasta region, which we specify as a bounding box and a time period corresponding to the Lava Fire (June 2021).

# %%
# Specify bounding box and time interval for search. Here we are using a bounding box over the Mt. Shasta. We'll use the time that corresponds to pre/post fire event.

search_bbox = BBox(bbox=[-122.36984252929688,41.5327401,-122.20436096,41.4195597], crs=CRS.WGS84)

search_time_interval = ('2021-05-12T00:00:00', '2021-09-14T23:59:59')


wfs_iterator = WebFeatureService(
    search_bbox,
    search_time_interval,
    data_collection=DataCollection.SENTINEL2_L1C,
    maxcc=1.0,
    config=config
)

for tile_info in wfs_iterator:
    print(tile_info)
# Out:
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS4_20210914T222623_A023634_T10TEL_N03.01', 'date': '2021-09-14', 'time': '19:13:03', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/9/14/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS4_20210914T222623_A023634_T10TEM_N03.01', 'date': '2021-09-14', 'time': '19:12:49', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/9/14/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.40882512266076, 41.550316030728496], [-122.47524921663147, 41.31949852428511], [-122.61309000966244, 40.88079946837772], [-122.68032616796654, 40.67057206017633], [-122.71149439176111, 40.562398689391735], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.40882512266076, 41.550316030728496]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210911T210319_A023591_T10TEL_N03.01', 'date': '2021-09-11', 'time': '19:03:07', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/9/11/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 1.36}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.12439996585096, 42.44933781670163], [-122.15858525251589, 42.33395189952812], [-122.43571848541193, 41.46237688724358], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.12439996585096, 42.44933781670163]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210911T210319_A023591_T10TEM_N03.01', 'date': '2021-09-11', 'time': '19:02:52', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/9/11/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 1.71}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210909T224700_A032471_T10TEL_N03.01', 'date': '2021-09-09', 'time': '19:13:07', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/9/9/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 60.93}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210909T224700_A032471_T10TEM_N03.01', 'date': '2021-09-09', 'time': '19:12:53', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/9/9/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 30.36}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.40714585355651, 41.550307385122636], [-122.47453574218785, 41.31913335126964], [-122.66778714222465, 40.70501027177745], [-122.7098393214702, 40.562394544431385], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.40714585355651, 41.550307385122636]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210906T223550_A032428_T10TEL_N03.01', 'date': '2021-09-06', 'time': '19:03:11', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/9/6/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 43.36}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.12245458377718, 42.44932293881188], [-122.15690047637581, 42.33285884455058], [-122.43404206255323, 41.46236865143022], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.12245458377718, 42.44932293881188]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210906T223550_A032428_T10TEM_N03.01', 'date': '2021-09-06', 'time': '19:02:56', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/9/6/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 3.18}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210904T211144_A023491_T10TEL_N03.01', 'date': '2021-09-04', 'time': '19:13:04', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/9/4/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210904T211144_A023491_T10TEM_N03.01', 'date': '2021-09-04', 'time': '19:12:49', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/9/4/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.40330936819385, 41.55028754121269], [-122.4699868010043, 41.320193565986536], [-122.66405622158476, 40.706200599875686], [-122.7062958334017, 40.56238559038976], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.40330936819385, 41.55028754121269]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210901T210126_A023448_T10TEL_N03.01', 'date': '2021-09-01', 'time': '19:03:07', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/9/1/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.11929262345367, 42.44929868631913], [-122.15449017177686, 42.33157972119761], [-122.4299712611291, 41.46234855098234], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.11929262345367, 42.44929868631913]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210901T210126_A023448_T10TEM_N03.01', 'date': '2021-09-01', 'time': '19:02:53', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/9/1/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210830T224939_A032328_T10TEL_N03.01', 'date': '2021-08-30', 'time': '19:13:09', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/8/30/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210830T224939_A032328_T10TEM_N03.01', 'date': '2021-08-30', 'time': '19:12:54', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/8/30/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.40858506885388, 41.550314796329715], [-122.4754928472577, 41.31895802854315], [-122.66734732854471, 40.71089516713212], [-122.71078479978608, 40.56239691519225], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.40858506885388, 41.550314796329715]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210827T223659_A032285_T10TEL_N03.01', 'date': '2021-08-27', 'time': '19:03:13', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/8/27/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.12342669414213, 42.44933037744378], [-122.15785259075956, 42.33430559867241], [-122.43571833756342, 41.46237688651832], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.12342669414213, 42.44933037744378]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210827T223659_A032285_T10TEM_N03.01', 'date': '2021-08-27', 'time': '19:02:58', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/8/27/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210825T211229_A023348_T10TEL_N03.01', 'date': '2021-08-25', 'time': '19:13:06', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/8/25/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 24.74}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210825T211229_A023348_T10TEM_N03.01', 'date': '2021-08-25', 'time': '19:12:51', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/8/25/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 1.67}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.40690627878911, 41.550306149688765], [-122.47405925008617, 41.318951093548264], [-122.68455014612945, 40.6516672088718], [-122.71031304062306, 40.56239573323636], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.40690627878911, 41.550306149688765]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210822T210133_A023305_T10TEL_N03.01', 'date': '2021-08-22', 'time': '19:03:10', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/8/22/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.12245429143417, 42.44932293657362], [-122.15714576589552, 42.33268007555345], [-122.43404210745476, 41.46236865165113], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.12245429143417, 42.44932293657362]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210822T210133_A023305_T10TEM_N03.01', 'date': '2021-08-22', 'time': '19:02:55', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/8/22/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS1_20210820T224919_A032185_T10TEL_N03.01', 'date': '2021-08-20', 'time': '19:13:10', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/8/20/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 1}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS1_20210820T224919_A032185_T10TEM_N03.01', 'date': '2021-08-20', 'time': '19:12:55', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/8/20/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 1.02}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.40762589518829, 41.55030985908854], [-122.47429228612694, 41.319673173305134], [-122.68322795342537, 40.657250025266215], [-122.71031365306668, 40.562395734772025], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.40762589518829, 41.55030985908854]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS4_20210817T222053_A032142_T10TEL_N03.01', 'date': '2021-08-17', 'time': '19:03:13', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/8/17/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0.21}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.12245436901578, 42.44932293716761], [-122.15714820997188, 42.33249982771062], [-122.4347603517051, 41.46237218318267], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.12245436901578, 42.44932293716761]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS4_20210817T222053_A032142_T10TEM_N03.01', 'date': '2021-08-17', 'time': '19:02:58', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/8/17/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0.14}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210815T211118_A023205_T10TEL_N03.01', 'date': '2021-08-15', 'time': '19:13:07', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/8/15/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0.04}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210815T211118_A023205_T10TEM_N03.01', 'date': '2021-08-15', 'time': '19:12:53', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/8/15/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.41074301148124, 41.550325874852184], [-122.47787967477603, 41.319328654273505], [-122.68053206721245, 40.67702748989849], [-122.71432801910045, 40.56240573088364], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.41074301148124, 41.550325874852184]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210812T210004_A023162_T10TEL_N03.01', 'date': '2021-08-12', 'time': '19:03:11', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/8/12/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0.01}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.12683192029444, 42.44935636935332], [-122.16025323421886, 42.336305889125896], [-122.43811326077096, 41.4623886097489], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.12683192029444, 42.44935636935332]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210812T210004_A023162_T10TEM_N03.01', 'date': '2021-08-12', 'time': '19:02:56', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/8/12/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210810T225350_A032042_T10TEL_N03.01', 'date': '2021-08-10', 'time': '19:13:10', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/8/10/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210810T225350_A032042_T10TEM_N03.01', 'date': '2021-08-10', 'time': '19:12:56', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/8/10/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.40618665120844, 41.550302435727545], [-122.47357981330386, 41.31912937212223], [-122.64379522338365, 40.776757785169444], [-122.6781912807945, 40.67164695111419], [-122.7088970637291, 40.562392174047794], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.40618665120844, 41.550302435727545]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS4_20210807T222103_A031999_T10TEL_N03.01', 'date': '2021-08-07', 'time': '19:03:14', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/8/7/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.12196865820502, 42.449319217396585], [-122.15617444773872, 42.33267406801527], [-122.43356303590798, 41.462366293613286], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.12196865820502, 42.449319217396585]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS4_20210807T222103_A031999_T10TEM_N03.01', 'date': '2021-08-07', 'time': '19:02:59', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/8/7/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210805T211134_A023062_T10TEL_N03.01', 'date': '2021-08-05', 'time': '19:13:09', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/8/5/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 1.81}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210805T211134_A023062_T10TEM_N03.01', 'date': '2021-08-05', 'time': '19:12:54', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/8/5/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 1.4}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.41314104904676, 41.55033813847356], [-122.48002451244238, 41.32005907543076], [-122.68626408736681, 40.66590327018712], [-122.7169264487373, 40.56241212682712], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.41314104904676, 41.55033813847356]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210802T210145_A023019_T10TEL_N03.01', 'date': '2021-08-02', 'time': '19:03:12', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/8/2/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 6.02}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.12902010210381, 42.44937301822882], [-122.16242394353053, 42.3374015831077], [-122.44074748055674, 41.46240144675776], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.12902010210381, 42.44937301822882]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210802T210145_A023019_T10TEM_N03.01', 'date': '2021-08-02', 'time': '19:02:57', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/8/2/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 1.27}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210731T224024_A031899_T10TEL_N03.01', 'date': '2021-07-31', 'time': '19:13:11', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/7/31/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 42.28}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210731T224024_A031899_T10TEM_N03.01', 'date': '2021-07-31', 'time': '19:12:56', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/7/31/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 75.82}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.40834533627206, 41.55031356308257], [-122.47501046026443, 41.31949677585903], [-122.64593033797419, 40.776403536617835], [-122.68056221123369, 40.670751733099316], [-122.71125910389878, 40.56239810158228], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.40834533627206, 41.55031356308257]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210728T223213_A031856_T10TEL_N03.01', 'date': '2021-07-28', 'time': '19:03:14', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/7/28/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 6.11}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.1241571529407, 42.44933596152113], [-122.15810021685853, 42.33394674528589], [-122.27781951964404, 41.96874746343278], [-122.29640635230083, 41.902755972738454], [-122.43547898909408, 41.4623757121587], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.1241571529407, 42.44933596152113]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210728T223213_A031856_T10TEM_N03.01', 'date': '2021-07-28', 'time': '19:02:59', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/7/28/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210726T211239_A022919_T10TEL_N03.01', 'date': '2021-07-26', 'time': '19:13:09', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/7/26/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 15.58}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210726T211239_A022919_T10TEM_N03.01', 'date': '2021-07-26', 'time': '19:12:55', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/7/26/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 14.5}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.41410012223574, 41.550343029195886], [-122.48072997945143, 41.32150339627812], [-122.65111894165376, 40.781284100018624], [-122.68790556837953, 40.6686167454432], [-122.70186579698839, 40.6155037437102], [-122.71881149721945, 40.56241673022999], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.41410012223574, 41.550343029195886]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210723T210319_A022876_T10TEL_N03.01', 'date': '2021-07-23', 'time': '19:03:13', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/7/23/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 18.07}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.1299930047623, 42.44938040718276], [-122.16340013623653, 42.33704710396816], [-122.28243480110648, 41.97191088691184], [-122.30767772719106, 41.88624785755739], [-122.44146592537906, 41.462404937393416], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.1299930047623, 42.44938040718276]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210723T210319_A022876_T10TEM_N03.01', 'date': '2021-07-23', 'time': '19:02:58', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/7/23/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS1_20210721T230008_A031756_T10TEL_N03.01', 'date': '2021-07-21', 'time': '19:13:11', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/7/21/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0.03}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS1_20210721T230008_A031756_T10TEM_N03.01', 'date': '2021-07-21', 'time': '19:12:56', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/7/21/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0.76}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.40810531055592, 41.550312327826695], [-122.4750093633907, 41.319675755523406], [-122.68056320563085, 40.67039412184606], [-122.71173054615856, 40.56239927888421], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.40810531055592, 41.550312327826695]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS4_20210718T222157_A031713_T10TEL_N03.01', 'date': '2021-07-18', 'time': '19:03:14', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/7/18/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.12415707593463, 42.4493359609327], [-122.15809721753885, 42.334128895919555], [-122.43547896299233, 41.46237571203059], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.12415707593463, 42.4493359609327]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS4_20210718T222157_A031713_T10TEM_N03.01', 'date': '2021-07-18', 'time': '19:02:59', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/7/18/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210716T211104_A022776_T10TEL_N03.01', 'date': '2021-07-16', 'time': '19:13:09', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/7/16/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 2.11}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210716T211104_A022776_T10TEM_N03.01', 'date': '2021-07-16', 'time': '19:12:55', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/7/16/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 1.04}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.4145796842615, 41.55034547168664], [-122.48120657447616, 41.321685368519965], [-122.68887696847491, 40.663722606493884], [-122.7188165883905, 40.56241674262129], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.4145796842615, 41.55034547168664]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210713T205848_A022733_T10TEL_N03.01', 'date': '2021-07-13', 'time': '19:03:13', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/7/13/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.13072266655301, 42.4493859433627], [-122.16336892461639, 42.33938901497699], [-122.28297499652022, 41.97113102509584], [-122.3039151889325, 41.89973574071435], [-122.44194490163758, 41.46240726205416], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.13072266655301, 42.4493859433627]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210713T205848_A022733_T10TEM_N03.01', 'date': '2021-07-13', 'time': '19:02:58', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/7/13/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210711T224050_A031613_T10TEL_N03.01', 'date': '2021-07-11', 'time': '19:13:10', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/7/11/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210711T224050_A031613_T10TEM_N03.01', 'date': '2021-07-11', 'time': '19:12:56', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/7/11/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.40642675610077, 41.55030367539731], [-122.4735841032061, 41.31858908247131], [-122.64451025756523, 40.77603875820021], [-122.67866390817657, 40.67182773082595], [-122.70960547624777, 40.562393956877365], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.40642675610077, 41.55030367539731]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS4_20210708T222235_A031570_T10TEL_N03.01', 'date': '2021-07-08', 'time': '19:03:14', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/7/8/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.12196821501422, 42.4493192140015], [-122.1564155535543, 42.332853403810766], [-122.27490344818136, 41.97052846833883], [-122.2977370092771, 41.89141314751008], [-122.43356300024608, 41.46236629343768], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.12196821501422, 42.4493192140015]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS4_20210708T222235_A031570_T10TEM_N03.01', 'date': '2021-07-08', 'time': '19:02:59', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/7/8/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210706T211657_A022633_T10TEL_N03.01', 'date': '2021-07-06', 'time': '19:13:09', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/7/6/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0.03}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210706T211657_A022633_T10TEM_N03.01', 'date': '2021-07-06', 'time': '19:12:55', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/7/6/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 2.86}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210701T223921_A031470_T10TEL_N03.01', 'date': '2021-07-01', 'time': '19:13:09', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/7/1/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0.09}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210701T223921_A031470_T10TEM_N03.01', 'date': '2021-07-01', 'time': '19:12:55', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/7/1/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0.36}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.40354910040156, 41.55028878495763], [-122.47046919502121, 41.31965497785907], [-122.6647658956812, 40.70629761728984], [-122.70676870408258, 40.56238679157109], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.40354910040156, 41.55028878495763]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210628T223226_A031427_T10TEL_N03.00', 'date': '2021-06-28', 'time': '19:03:12', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/6/28/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.11929328046783, 42.44929869136753], [-122.15400204281401, 42.33175698796178], [-122.43068941531487, 41.462352107487405], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.11929328046783, 42.44929869136753]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210628T223226_A031427_T10TEM_N03.00', 'date': '2021-06-28', 'time': '19:02:58', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/6/28/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210626T211041_A022490_T10TEL_N03.00', 'date': '2021-06-26', 'time': '19:13:08', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/6/26/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0.02}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210626T211041_A022490_T10TEM_N03.00', 'date': '2021-06-26', 'time': '19:12:54', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/6/26/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.41026359589351, 41.55032341711069], [-122.47716301171147, 41.31932466712419], [-122.58134984016084, 40.99419413569048], [-122.6158480354627, 40.8795826107015], [-122.0526014408891, 40.79920544833497], [-121.73942563427775, 40.745108459993205], [-121.73363793456853, 40.746836289232355], [-121.69978082427068, 40.74085855449056], [-121.68381174361195, 41.54430266694568], [-122.41026359589351, 41.55032341711069]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210623T210214_A022447_T10TEL_N03.00', 'date': '2021-06-23', 'time': '19:03:09', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/6/23/1', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0.9}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.12561585477832, 42.44934709880492], [-122.15929014512943, 42.335756062267635], [-122.27889078142599, 41.97055485420681], [-122.29784139502954, 41.903844859372626], [-122.43715537547831, 41.46238392685134], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.12561585477832, 42.44934709880492]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210623T210214_A022447_T10TEM_N03.00', 'date': '2021-06-23', 'time': '19:02:56', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/6/23/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 2.46}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS1_20210621T224855_A031327_T10TEL_N03.00', 'date': '2021-06-21', 'time': '19:13:08', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/6/21/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 2.95}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS1_20210621T224855_A031327_T10TEM_N03.00', 'date': '2021-06-21', 'time': '19:12:54', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/6/21/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 2.37}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.39971225660814, 41.550268819167705], [-122.46664421831443, 41.31981822897463], [-122.5989686178638, 40.900028829297185], [-122.67155621291228, 40.67343183357411], [-122.70299046384864, 40.562377140073835], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.39971225660814, 41.550268819167705]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS4_20210618T222534_A031284_T10TEL_N03.00', 'date': '2021-06-18', 'time': '19:03:11', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/6/18/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0}}
# ...
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.11856374322728, 42.44929308337542], [-122.15352862169209, 42.330852990210595], [-122.42973155607055, 41.46234736289623], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.11856374322728, 42.44929308337542]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS4_20210608T222246_A031141_T10TEM_N03.00', 'date': '2021-06-08', 'time': '19:02:57', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/6/8/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 52.11}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210606T211805_A022204_T10TEL_N03.00', 'date': '2021-06-06', 'time': '19:13:08', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/6/6/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 1.13}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210606T211805_A022204_T10TEM_N03.00', 'date': '2021-06-06', 'time': '19:12:54', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/6/6/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 25.59}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.41577870630887, 41.55035156975735], [-122.48191058861987, 41.323310042652096], [-122.68477747948853, 40.68013269815867], [-122.71976125761427, 40.56241903795006], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.41577870630887, 41.55035156975735]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210603T210222_A022161_T10TEL_N03.00', 'date': '2021-06-03', 'time': '19:03:12', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/6/3/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0.04}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.13169482223715, 42.4493933122041], [-122.16432362632183, 42.34065576354172], [-122.2835583357441, 41.97364483855888], [-122.3048715163362, 41.90046288371048], [-122.44290291947165, 41.462411905708464], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.13169482223715, 42.4493933122041]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210603T210222_A022161_T10TEM_N03.00', 'date': '2021-06-03', 'time': '19:02:57', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/6/3/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0.23}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210601T224546_A031041_T10TEL_N03.00', 'date': '2021-06-01', 'time': '19:13:08', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/6/1/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 3.09}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210601T224546_A031041_T10TEM_N03.00', 'date': '2021-06-01', 'time': '19:12:54', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/6/1/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.40618687705049, 41.5503024368938], [-122.47334249831626, 41.318947441342274], [-122.67818779192501, 40.672190737662525], [-122.70936898225925, 40.56239336218673], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.40618687705049, 41.5503024368938]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210529T222959_A030998_T10TEL_N03.00', 'date': '2021-05-29', 'time': '19:03:12', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/5/29/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0.02}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.12221176691689, 42.449321079479326], [-122.15641532168162, 42.33285411471273], [-122.27565515222975, 41.968014311769274], [-122.29399902757214, 41.902381544942024], [-122.43308416114172, 41.46236393454995], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.12221176691689, 42.449321079479326]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210529T222959_A030998_T10TEM_N03.00', 'date': '2021-05-29', 'time': '19:02:57', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/5/29/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210527T211301_A022061_T10TEL_N03.00', 'date': '2021-05-27', 'time': '19:13:08', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/5/27/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 44.39}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210527T211301_A022061_T10TEM_N03.00', 'date': '2021-05-27', 'time': '19:12:54', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/5/27/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 47.61}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.41505919365854, 41.55034791190956], [-122.4814354582418, 41.322947777836035], [-122.65158712835357, 40.782367198018605], [-122.68885601687631, 40.66771923553433], [-122.70233500737791, 40.61622735494973], [-122.71928491821079, 40.56241788152045], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.41505919365854, 41.55034791190956]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210524T211447_A022018_T10TEL_N03.00', 'date': '2021-05-24', 'time': '19:03:11', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/5/24/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 15.16}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.13120901819389, 42.449389630889605], [-122.16359937010864, 42.340292596521664], [-122.44266334259021, 41.46241074519203], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.13120901819389, 42.449389630889605]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210524T211447_A022018_T10TEM_N03.00', 'date': '2021-05-24', 'time': '19:02:56', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/5/24/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 13.08}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS4_20210523T002123_A030898_T10TEL_N03.00', 'date': '2021-05-22', 'time': '19:13:08', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/5/22/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 70.48}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS4_20210523T002123_A030898_T10TEM_N03.00', 'date': '2021-05-22', 'time': '19:12:54', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/5/22/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 68.51}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.40642653102343, 41.55030367423544], [-122.47382196483235, 41.31876912422766], [-122.67817864460716, 40.674171406377894], [-122.71031328090633, 40.56239573383885], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.40642653102343, 41.55030367423544]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS4_20210520T001103_A030855_T10TEL_N03.00', 'date': '2021-05-19', 'time': '19:03:11', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/5/19/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 8.85}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.12245472221014, 42.44932293987176], [-122.15665084800143, 42.3333962313628], [-122.27515929192697, 41.96926863235171], [-122.29798221118087, 41.8910538166454], [-122.4330843457258, 41.46236393545964], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.12245472221014, 42.44932293987176]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS4_20210520T001103_A030855_T10TEM_N03.00', 'date': '2021-05-19', 'time': '19:02:56', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/5/19/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 9.04}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210517T211615_A021918_T10TEL_N03.00', 'date': '2021-05-17', 'time': '19:13:07', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/5/17/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 2.29}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210517T211615_A021918_T10TEM_N03.00', 'date': '2021-05-17', 'time': '19:12:52', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/5/17/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 1.47}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.41314108859858, 41.55033813867542], [-122.48002589167476, 41.319879103100156], [-122.65041539333689, 40.77984073193467], [-122.68720340814237, 40.66699289626345], [-122.70068073565822, 40.61604309809837], [-122.71739565107686, 40.56241327552285], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-122.41314108859858, 41.55033813867542]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210514T210033_A021875_T10TEL_N03.00', 'date': '2021-05-14', 'time': '19:03:10', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/5/14/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 69.93}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-122.12926380055522, 42.44937486983332], [-122.16191895993, 42.33883992879125], [-122.44026863066982, 41.462399117725774], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-122.12926380055522, 42.44937486983332]]]]}, 'properties': {'id': 'S2B_OPER_MSI_L1C_TL_VGS1_20210514T210033_A021875_T10TEM_N03.00', 'date': '2021-05-14', 'time': '19:02:55', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/5/14/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 16.85}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.0002278281736, 41.55183566201435], [-123.00022444079164, 40.56275892162145], [-121.70337428841314, 40.555482279532676], [-121.68381174361195, 41.54430266694568], [-123.0002278281736, 41.55183566201435]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210512T223857_A030755_T10TEL_N03.00', 'date': '2021-05-12', 'time': '19:13:07', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EL/2021/5/12/0', 'crs': 'EPSG:32610', 'mbr': '499980,4490220 609780,4600020', 'cloudCoverPercentage': 0.71}}
# {'type': 'Feature', 'geometry': {'type': 'MultiPolygon', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}, 'coordinates': [[[[-123.00023106468512, 42.45268219265066], [-123.00022751961944, 41.4637608939765], [-121.68559366898083, 41.45625103879976], [-121.66512078076381, 42.444908861830775], [-123.00023106468512, 42.45268219265066]]]]}, 'properties': {'id': 'S2A_OPER_MSI_L1C_TL_VGS2_20210512T223857_A030755_T10TEM_N03.00', 'date': '2021-05-12', 'time': '19:12:53', 'path': 's3://sentinel-s2-l1c/tiles/10/T/EM/2021/5/12/0', 'crs': 'EPSG:32610', 'mbr': '499980,4590240 609780,4700040', 'cloudCoverPercentage': 0.01}}

# %%
# List available tiles
wfs_iterator.get_tiles()
# Out:
# [('10TEL', '2021-9-14', 0),
#  ('10TEM', '2021-9-14', 0),
#  ('10TEL', '2021-9-11', 0),
#  ('10TEM', '2021-9-11', 0),
#  ('10TEL', '2021-9-9', 0),
#  ('10TEM', '2021-9-9', 0),
#  ('10TEL', '2021-9-6', 0),
#  ('10TEM', '2021-9-6', 0),
#  ('10TEL', '2021-9-4', 0),
#  ('10TEM', '2021-9-4', 0),
#  ('10TEL', '2021-9-1', 0),
#  ('10TEM', '2021-9-1', 0),
#  ('10TEL', '2021-8-30', 0),
#  ('10TEM', '2021-8-30', 0),
#  ('10TEL', '2021-8-27', 0),
#  ('10TEM', '2021-8-27', 0),
#  ('10TEL', '2021-8-25', 0),
#  ('10TEM', '2021-8-25', 0),
#  ('10TEL', '2021-8-22', 0),
#  ('10TEM', '2021-8-22', 0),
#  ('10TEL', '2021-8-20', 0),
#  ('10TEM', '2021-8-20', 0),
#  ('10TEL', '2021-8-17', 0),
#  ('10TEM', '2021-8-17', 0),
#  ('10TEL', '2021-8-15', 0),
#  ('10TEM', '2021-8-15', 0),
#  ('10TEL', '2021-8-12', 0),
#  ('10TEM', '2021-8-12', 0),
#  ('10TEL', '2021-8-10', 0),
#  ('10TEM', '2021-8-10', 0),
#  ('10TEL', '2021-8-7', 0),
#  ('10TEM', '2021-8-7', 0),
#  ('10TEL', '2021-8-5', 0),
#  ('10TEM', '2021-8-5', 0),
#  ('10TEL', '2021-8-2', 0),
#  ('10TEM', '2021-8-2', 0),
#  ('10TEL', '2021-7-31', 0),
#  ('10TEM', '2021-7-31', 0),
#  ('10TEL', '2021-7-28', 0),
#  ('10TEM', '2021-7-28', 0),
#  ('10TEL', '2021-7-26', 0),
#  ('10TEM', '2021-7-26', 0),
#  ('10TEL', '2021-7-23', 0),
#  ('10TEM', '2021-7-23', 0),
#  ('10TEL', '2021-7-21', 0),
#  ('10TEM', '2021-7-21', 0),
#  ('10TEL', '2021-7-18', 0),
#  ('10TEM', '2021-7-18', 0),
#  ('10TEL', '2021-7-16', 0),
#  ('10TEM', '2021-7-16', 0),
#  ('10TEL', '2021-7-13', 0),
#  ('10TEM', '2021-7-13', 0),
#  ('10TEL', '2021-7-11', 0),
#  ('10TEM', '2021-7-11', 0),
#  ('10TEL', '2021-7-8', 0),
#  ('10TEM', '2021-7-8', 0),
#  ('10TEL', '2021-7-6', 0),
#  ('10TEM', '2021-7-6', 0),
#  ('10TEL', '2021-7-1', 0),
#  ('10TEM', '2021-7-1', 0),
#  ('10TEL', '2021-6-28', 0),
#  ('10TEM', '2021-6-28', 0),
#  ('10TEL', '2021-6-26', 0),
#  ('10TEM', '2021-6-26', 0),
#  ('10TEL', '2021-6-23', 1),
#  ('10TEM', '2021-6-23', 0),
#  ('10TEL', '2021-6-21', 0),
#  ('10TEM', '2021-6-21', 0),
#  ('10TEL', '2021-6-18', 0),
#  ('10TEM', '2021-6-18', 0),
#  ('10TEL', '2021-6-16', 0),
#  ('10TEM', '2021-6-16', 0),
#  ('10TEL', '2021-6-13', 0),
#  ('10TEM', '2021-6-13', 0),
#  ('10TEL', '2021-6-11', 0),
#  ('10TEM', '2021-6-11', 0),
#  ('10TEL', '2021-6-8', 0),
#  ('10TEM', '2021-6-8', 0),
#  ('10TEL', '2021-6-6', 0),
#  ('10TEM', '2021-6-6', 0),
#  ('10TEL', '2021-6-3', 0),
#  ('10TEM', '2021-6-3', 0),
#  ('10TEL', '2021-6-1', 0),
#  ('10TEM', '2021-6-1', 0),
#  ('10TEL', '2021-5-29', 0),
#  ('10TEM', '2021-5-29', 0),
#  ('10TEL', '2021-5-27', 0),
#  ('10TEM', '2021-5-27', 0),
#  ('10TEL', '2021-5-24', 0),
#  ('10TEM', '2021-5-24', 0),
#  ('10TEL', '2021-5-22', 0),
#  ('10TEM', '2021-5-22', 0),
#  ('10TEL', '2021-5-19', 0),
#  ('10TEM', '2021-5-19', 0),
#  ('10TEL', '2021-5-17', 0),
#  ('10TEM', '2021-5-17', 0),
#  ('10TEL', '2021-5-14', 0),
#  ('10TEM', '2021-5-14', 0),
#  ('10TEL', '2021-5-12', 0),
#  ('10TEM', '2021-5-12', 0)]

# %% [markdown]
# #### Picking Tiles
# For best results, we pick a tile with least cloud coverage.

# %%
from sentinelhub import AwsTile

tile_id = 'S2A_OPER_MSI_L1C_TL_VGS2_20210512T223857_A030755_T10TEL_N03.00'
tile_name, time, aws_index = AwsTile.tile_id_to_tile(tile_id)
tile_name, time, aws_index

tile_id2 = 'S2B_OPER_MSI_L1C_TL_VGS4_20210914T222623_A023634_T10TEL_N03.01'
tile_name2, time2, aws_index2 = AwsTile.tile_id_to_tile(tile_id2)
tile_name2, time2, aws_index2
# Out:
# ('10TEL', '2021-9-14', 0)

# %% [markdown]
# #### Sentinel Data Download
# The Sentinel-2 satellites each carry a single multi-spectral instrument (MSI) with 13 spectral channels in the visible/near infrared (VNIR) and short wave infrared spectral range (SWIR). You can read more about these bands [here](https://en.wikipedia.org/wiki/Sentinel-2#Spectral_bands). For our example will download eight specific bands that will aid our analysis.

# %%
warnings.simplefilter("ignore", UserWarning)
from sentinelhub import AwsTileRequest

bands = ['B04','B08']  # Sentinel-2 imagery is comprised of several bands but we are only focusing on these for this analysis
metafiles = ['tileInfo', 'preview', 'qi/MSK_CLOUDS_B00']
data_folder = './AwsData'

request = AwsTileRequest(   # This corresponds to the first image request
    tile=tile_name,
    time=time,
    aws_index=aws_index,
    bands=bands,
    metafiles=metafiles,
    data_folder=data_folder,
    data_collection=DataCollection.SENTINEL2_L1C
)

request.save_data()  # This is where the download is triggered

request2 = AwsTileRequest(   # This corresponds to the second image request
    tile=tile_name2,
    time=time2,
    aws_index=aws_index2,
    bands=bands,
    metafiles=metafiles,
    data_folder=data_folder,
    data_collection=DataCollection.SENTINEL2_L1C
)

request2.save_data()

# %% [markdown]
# ## Working with Raster Data
# Geospatial data is essentially comprised of raster data or vector data. Sentinel-2 uses GeoTIFF, a gridded raster datasets for satellite imagery and terrain models. Rasterio is a Python library that allows to read, inspect, visualize and write geospatial raster data. Here we use `rasterio` to read thee raster arrays and then use this data to create a true color image.

# %%
import rasterio
from rasterio import plot
import earthpy.spatial as es
import earthpy.plot as ep

# %% [markdown]
# The `earthpy` package allows easy plotting of visualization of bands, we use it here to visualize the NDVI

# %% [markdown]
# ### Calculating Spectral Indices
# Spectral indices are combinations of the pixel values from two or more spectral bands in a multispectral image. Spectral indices highlight pixels showing the relative abundance or lack of a land-cover type of interest in an image. Let's looks at a couple

# %% [markdown]
# ### Normalized Difference Vegetation Index - NVDI
# The normalized difference vegetation index is a simple graphical indicator that can be used to analyze whether or not the target being observed contains live green vegetation.

# %% [markdown]
# It calculated as `NDVI = (NIR – Red) / (NIR + Red)`

# %%
band4_image1 = rasterio.open('./AwsData/10TEL,2021-05-12,0/B04.jp2', driver='JP2OpenJPEG') #red
band8_image1 = rasterio.open('./AwsData/10TEL,2021-05-12,0/B08.jp2', driver='JP2OpenJPEG') #nir

band4_image2 = rasterio.open('./AwsData/10TEL,2021-09-14,0/B04.jp2', driver='JP2OpenJPEG') #red
band8_image2 = rasterio.open('./AwsData/10TEL,2021-09-14,0/B08.jp2', driver='JP2OpenJPEG') #nir

# read Red(b4) and NIR(b8) as arrays
red_image1 = band4_image1.read(1)
nir_image1 = band8_image1.read(1)
ndvi_image1 = (nir_image1.astype(float)-red_image1.astype(float))/(nir_image1.astype(float)+red_image1.astype(float))

red_image2 = band4_image2.read(1)
nir_image2 = band8_image2.read(1)
ndvi_image2 = (nir_image2.astype(float)-red_image2.astype(float))/(nir_image2.astype(float)+red_image2.astype(float))

# %% [markdown]
# ### Creating a Simple Image Classification from NDVI
# Remote Sensing data can be classified into thematic layers like land cover maps which are useful for representing spectral values as vegetation. This next section will create a 5-class map from the input NDVI images to compare differences in land cover change before and after the Lava Fire event occurred.

# %%
# Create classes and apply to NDVI results
ndvi_class_bins = [-np.inf, 0, 0.1, 0.25, 0.4, np.inf]
ndvi_sentinel_class = np.digitize(ndvi_image1, ndvi_class_bins)

# Apply the nodata mask to the newly classified NDVI data
ndvi_sentinel_class = np.ma.masked_where(
    np.ma.getmask(ndvi_image1), ndvi_sentinel_class
)
#np.unique(ndvi_sentinel_class)

from matplotlib.colors import ListedColormap

# Define color map
nbr_colors = ["khaki", "y", "yellowgreen", "g", "darkgreen"]
nbr_cmap = ListedColormap(nbr_colors)

# Define class names
ndvi_cat_names = [
    "Dead forest",
    "Scrub",
    "Open Forest",
    "Moderately Dense Forest",
    "Very Dense Forest",
]

# Get list of classes
classes = np.unique(ndvi_sentinel_class)
classes = classes.tolist()

# The mask returns a value of none in the classes. remove that
classes = classes[0:5]

# Create classes and apply to NDVI results
ndvi_class_bins_2 = [-np.inf, 0, 0.1, 0.25, 0.4, np.inf]
ndvi_sentinel_class_2 = np.digitize(ndvi_image2, ndvi_class_bins)

# Apply the nodata mask to the newly classified NDVI data
ndvi_sentinel_class_2 = np.ma.masked_where(
    np.ma.getmask(ndvi_image2), ndvi_sentinel_class_2
)
#np.unique(ndvi_sentinel_class_2)

nbr_colors_2 = ["khaki", "y", "yellowgreen", "g", "darkgreen"]
nbr_cmap_2 = ListedColormap(nbr_colors)

# Define class names
ndvi_cat_names_2 = [
    "Dead forest",
    "Scrub",
    "Open Forest",
    "Moderately Dense Forest",
    "Very Dense Forest",
]

# Get list of classes
classes_2 = np.unique(ndvi_sentinel_class_2)
classes_2 = classes_2.tolist()
# The mask returns a value of none in the classes. remove that
classes_2 = classes_2[0:5]

# %% [markdown]
# ## Plotting the Images

# %% [markdown]
# ### NDVI Image Comparison

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,6)) # 2 axes on a 1x2 grid

ndvi_image1 = ax1.imshow(ndvi_image1, cmap="RdYlGn")
ax1.set_title("NDVI (Pre) - 2021-05-12")
ndvi_image1.set_clim(vmin=-1, vmax=1)
fig.colorbar(ndvi_image1, ax=ax1)

# Now red band in the second subplot
ndvi_image2 = ax2.imshow(ndvi_image2, cmap="RdYlGn")
ax2.set_title("NDVI (Post) - 2021-09-14 ")
ndvi_image2.set_clim(vmin=-1, vmax=1)
fig.colorbar(ndvi_image2, ax=ax2)

# %% [markdown]
# You can see areas with vegetation in green, areas with dense vegetation as darker shades of green, water bodes generally have low to no vegetation and as such in a contrasting shade of orange.

# %% [markdown]
# ### Vegetation Classification Maps

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,6)) # 2 axes on a 1x2 grid

im1 = ax1.imshow(np.squeeze(ndvi_sentinel_class), cmap=nbr_cmap)
ep.draw_legend(im_ax=im1, classes=classes, titles=ndvi_cat_names)
ax1.set_title(
    "Pre-fire (2021-05-12)",
    fontsize=14)
ax1.set_axis_off()

# Auto adjust subplot to fit figure size
#plt.tight_layout()


im2 = ax2.imshow(np.squeeze(ndvi_sentinel_class_2), cmap=nbr_cmap_2)

#ep.draw_legend(im_ax=im2, classes=classes_2, titles=ndvi_cat_names_2)
ax2.set_title(
    "Post-fire (2021-09-14)",
    fontsize=14,
)
ax2.set_axis_off()

# Auto adjust subplot to fit figure size
#plt.tight_layout()

# %% [markdown]
# Here we see a comparison of pre/post fire classified NDVI images using some common vegetation classes representing different NDVI value ranges. Visually we see large areas of Very Dense / Moderately Dense Forest transformed into Dead Forest or Scrub following events of the Lava Fire.

# %% [markdown]
# ## Clean Up (Optional)
# Though we did not create any AWS billable resources as part of this exercise, the geographic and GIS data that we downloaded and the images generated may take up significant storage. Make sure to check any storage utilization and delete the files as needed.
